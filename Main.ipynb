# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Store CSV into DataFrame

# %%
csv_file = "Resources/Happiness2015.csv"
happiness_data_2015_df = pd.read_csv(csv_file)
happiness_data_2015_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
happiness_data_2015_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
happiness_data_2015_df.drop(columns=['Standard Error']).head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176

# %%
happiness_data_2015_df['Year'] = 2015
happiness_data_2015_df

cleaned_happiness_data_2015_df = happiness_data_2015_df.drop(columns=['Standard Error']).head()
cleaned_happiness_data_2015_df
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                        0.41978     0.29678            2.51738  2015
# 1                        0.14145     0.43630            2.70201  2015
# 2                        0.48357     0.34139            2.49204  2015
# 3                        0.36503     0.34699            2.46531  2015
# 4                        0.32957     0.45811            2.45176  2015

# %%
csv_file = "Resources/Happiness2016.csv"
happiness_data_2016_df = pd.read_csv(csv_file)
happiness_data_2016_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
happiness_data_2016_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
happiness_data_2016_df.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval']).head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
happiness_data_2016_df['Year'] = 2016
happiness_data_2016_df

cleaned_happiness_data_2016_df = happiness_data_2016_df.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval'])
cleaned_happiness_data_2016_df
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.526                   1.44178  1.16374
# 1              7.509                   1.52733  1.14524
# 2              7.501                   1.42666  1.18326
# 3              7.498                   1.57744  1.12690
# 4              7.413                   1.40598  1.13464
# ..               ...                       ...      ...
# 152            3.484                   0.39499  0.10419
# 153            3.360                   0.38227  0.11037
# 154            3.303                   0.28123  0.00000
# 155            3.069                   0.74719  0.14866
# 156            2.905                   0.06831  0.23442
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.79504  0.57941                        0.44453
# 1                     0.86303  0.58557                        0.41203
# 2                     0.86733  0.56624                        0.14975
# 3                     0.79579  0.59609                        0.35776
# 4                     0.81091  0.57104                        0.41004
# ..                        ...      ...                            ...
# 152                   0.21028  0.39747                        0.06681
# 153                   0.17344  0.16430                        0.07112
# 154                   0.24811  0.34678                        0.11587
# 155                   0.62994  0.06912                        0.17233
# 156                   0.15747  0.04320                        0.09419
#
#      Generosity  Dystopia Residual  Year
# 0       0.36171            2.73939  2016
# 1       0.28083            2.69463  2016
# 2       0.47678            2.83137  2016
# 3       0.37895            2.66465  2016
# 4       0.25492            2.82596  2016
# ..          ...                ...   ...
# 152     0.20180            2.10812  2016
# 153     0.31268            2.14558  2016
# 154     0.17517            2.13540  2016
# 155     0.48397            0.81789  2016
# 156     0.20290            2.10404  2016
#
# [157 rows x 12 columns]

# %%
new_happy_results = pd.concat([cleaned_happiness_data_2015_df, cleaned_happiness_data_2016_df], ignore_index=True)
new_happy_results
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 157        Benin               Sub-Saharan Africa             153
# 158  Afghanistan                    Southern Asia             154
# 159         Togo               Sub-Saharan Africa             155
# 160        Syria  Middle East and Northern Africa             156
# 161      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 157            3.484                   0.39499  0.10419
# 158            3.360                   0.38227  0.11037
# 159            3.303                   0.28123  0.00000
# 160            3.069                   0.74719  0.14866
# 161            2.905                   0.06831  0.23442
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 157                   0.21028  0.39747                        0.06681
# 158                   0.17344  0.16430                        0.07112
# 159                   0.24811  0.34678                        0.11587
# 160                   0.62994  0.06912                        0.17233
# 161                   0.15747  0.04320                        0.09419
#
#      Generosity  Dystopia Residual  Year
# 0       0.29678            2.51738  2015
# 1       0.43630            2.70201  2015
# 2       0.34139            2.49204  2015
# 3       0.34699            2.46531  2015
# 4       0.45811            2.45176  2015
# ..          ...                ...   ...
# 157     0.20180            2.10812  2016
# 158     0.31268            2.14558  2016
# 159     0.17517            2.13540  2016
# 160     0.48397            0.81789  2016
# 161     0.20290            2.10404  2016
#
# [162 rows x 12 columns]

# %%
new_happy_results.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
csv_file = "Resources/who_suicide_statistics.csv"
who_suicide_df = pd.read_csv(csv_file)
who_suicide_df.head()
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1985  female  15-24 years          NaN    277900.0
# 1  Albania  1985  female  25-34 years          NaN    246800.0
# 2  Albania  1985  female  35-54 years          NaN    267500.0
# 3  Albania  1985  female   5-14 years          NaN    298300.0
# 4  Albania  1985  female  55-74 years          NaN    138700.0

# %%
who_suicide_df.dropna(inplace=True)
who_suicide_df
# Out:
#                     country  year     sex          age  suicides_no  \
# 24                  Albania  1987  female  15-24 years         14.0
# 25                  Albania  1987  female  25-34 years          4.0
# 26                  Albania  1987  female  35-54 years          6.0
# 27                  Albania  1987  female   5-14 years          0.0
# 28                  Albania  1987  female  55-74 years          0.0
# ...                     ...   ...     ...          ...          ...
# 43759  Virgin Islands (USA)  2015    male  25-34 years          2.0
# 43760  Virgin Islands (USA)  2015    male  35-54 years          1.0
# 43761  Virgin Islands (USA)  2015    male   5-14 years          0.0
# 43762  Virgin Islands (USA)  2015    male  55-74 years          0.0
# 43763  Virgin Islands (USA)  2015    male    75+ years          0.0
#
#        population
# 24       289700.0
# 25       257200.0
# 26       278800.0
# 27       311000.0
# 28       144600.0
# ...           ...
# 43759      4609.0
# 43760     12516.0
# 43761      7291.0
# 43762     12615.0
# 43763      2496.0
#
# [36060 rows x 6 columns]

# %%
filtered_suicide = who_suicide_df.loc[who_suicide_df['year'] > 2014]
filtered_suicide
# Out:
#                     country  year     sex          age  suicides_no  \
# 1044    Antigua and Barbuda  2015  female  15-24 years          0.0
# 1045    Antigua and Barbuda  2015  female  25-34 years          0.0
# 1046    Antigua and Barbuda  2015  female  35-54 years          0.0
# 1047    Antigua and Barbuda  2015  female   5-14 years          0.0
# 1048    Antigua and Barbuda  2015  female  55-74 years          1.0
# ...                     ...   ...     ...          ...          ...
# 43759  Virgin Islands (USA)  2015    male  25-34 years          2.0
# 43760  Virgin Islands (USA)  2015    male  35-54 years          1.0
# 43761  Virgin Islands (USA)  2015    male   5-14 years          0.0
# 43762  Virgin Islands (USA)  2015    male  55-74 years          0.0
# 43763  Virgin Islands (USA)  2015    male    75+ years          0.0
#
#        population
# 1044       8561.0
# 1045       7740.0
# 1046      15323.0
# 1047       8239.0
# 1048       6403.0
# ...           ...
# 43759      4609.0
# 43760     12516.0
# 43761      7291.0
# 43762     12615.0
# 43763      2496.0
#
# [1056 rows x 6 columns]

# %%
filtered_suicide.dtypes
# Out:
# country         object
# year             int64
# sex             object
# age             object
# suicides_no    float64
# population     float64
# dtype: object

# %%
filtered_suicide['suicide_rate'] = filtered_suicide ["suicides_no"] / filtered_suicide["population"]
filtered_suicide
# Out:
# /Users/luisbejaran/opt/miniconda3/envs/pythondata/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     country  year     sex          age  suicides_no  \
# 1044    Antigua and Barbuda  2015  female  15-24 years          0.0
# 1045    Antigua and Barbuda  2015  female  25-34 years          0.0
# 1046    Antigua and Barbuda  2015  female  35-54 years          0.0
# 1047    Antigua and Barbuda  2015  female   5-14 years          0.0
# 1048    Antigua and Barbuda  2015  female  55-74 years          1.0
# ...                     ...   ...     ...          ...          ...
# 43759  Virgin Islands (USA)  2015    male  25-34 years          2.0
# 43760  Virgin Islands (USA)  2015    male  35-54 years          1.0
# 43761  Virgin Islands (USA)  2015    male   5-14 years          0.0
# 43762  Virgin Islands (USA)  2015    male  55-74 years          0.0
# 43763  Virgin Islands (USA)  2015    male    75+ years          0.0
#
#        population  suicide_rate
# 1044       8561.0      0.000000
# 1045       7740.0      0.000000
# 1046      15323.0      0.000000
# 1047       8239.0      0.000000
# 1048       6403.0      0.000156
# ...           ...           ...
# 43759      4609.0      0.000434
# 43760     12516.0      0.000080
# 43761      7291.0      0.000000
# 43762     12615.0      0.000000
# 43763      2496.0      0.000000
#
# [1056 rows x 7 columns]
